# %%
class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

vehicle1 = Vehicle(180, 24)
print(f"Max speed of this vehicle is {vehicle1.max_speed} and its mileage/ltr {vehicle1.mileage}")
# Out:
# Max speed of this vehicle is 180 and its mileage/ltr 24

# %%
class Vehicle:
    pass

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage        


class Bus(Vehicle):
    def __init__(self, name, max_speed, mileage)
        super().__init__(name, max_speed, mileage)
