# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwanahmed1981/SMIT-AI-DS/blob/main/machine_learning_lacture3_with__Dr__Shazia_Saqib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_dataset_1000.csv")

# %%
df.head()
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 0   1    Paul   25  Female  90041.86   2017-01-31      False
# 1   2    Paul   31    Male  90285.02   2019-05-29      False
# 2   3  Rachel   30    Male  84321.65   2022-12-14      False
# 3   4     Bob   45    Male  68189.99   2023-09-05       True
# 4   5     Eve   34    Male  35428.35   2018-05-19       True
#
#             Comments
# 0           Creative
# 1  Needs Improvement
# 2        Hardworking
# 3       Fast Learner
# 4          Dedicated

# %%
df.shape
# Out:
# (1000, 8)

# %%
x = df[['Salary']]
x
x.shape
# Out:
# (1000, 1)

# %%
x.head()
# Out:
#      Salary
# 0  90041.86
# 1  90285.02
# 2  84321.65
# 3  68189.99
# 4  35428.35

# %%
y =df[['Name', 'Salary']]

# %%
y.head()
# Out:
#      Name    Salary
# 0    Paul  90041.86
# 1    Paul  90285.02
# 2  Rachel  84321.65
# 3     Bob  68189.99
# 4     Eve  35428.35

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
print(y.dtypes)
# Out:
# Name       object
# Salary    float64
# dtype: object

# %%
#df.iloc[:]
#df.iloc[:2]
#df.iloc[0,0:2]
#indexing is like this [start:end:step]
df.iloc[:5,:5] # here [row indexing,column indexing] comma seperates row and columns
# Out:
#    ID    Name  Age  Gender    Salary
# 0   1    Paul   25  Female  90041.86
# 1   2    Paul   31    Male  90285.02
# 2   3  Rachel   30    Male  84321.65
# 3   4     Bob   45    Male  68189.99
# 4   5     Eve   34    Male  35428.35

# %%
df.iloc[:5,:7]
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active
# 0   1    Paul   25  Female  90041.86   2017-01-31      False
# 1   2    Paul   31    Male  90285.02   2019-05-29      False
# 2   3  Rachel   30    Male  84321.65   2022-12-14      False
# 3   4     Bob   45    Male  68189.99   2023-09-05       True
# 4   5     Eve   34    Male  35428.35   2018-05-19       True

# %%
df.iloc[0:2,0:6]
# Out:
#    ID  Name  Age  Gender    Salary Joining Date
# 0   1  Paul   25  Female  90041.86   2017-01-31
# 1   2  Paul   31    Male  90285.02   2019-05-29

# %%
df.iloc[3:7,1:3]
# Out:
#      Name  Age
# 3     Bob   45
# 4     Eve   34
# 5  Hannah   23
# 6   Oscar   23

# %%
df.loc[0:2,['Joining Date','Salary']]
# Out:
#   Joining Date    Salary
# 0   2017-01-31  90041.86
# 1   2019-05-29  90285.02
# 2   2022-12-14  84321.65

# %%
df.iloc[0:2,['Joining Date','Salary']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-377528679.py in <cell line: 0>()
# ----> 1 df.iloc[0:2,['Joining Date','Salary']]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1688
#    1689     def _getitem_tuple(self, tup: tuple):
# -> 1690         tup = self._validate_tuple_indexer(tup)
#    1691         with suppress(IndexingError):
#    1692             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[4:6]
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 4   5     Eve   34    Male  35428.35   2018-05-19       True
# 5   6  Hannah   23   Other  33952.28   2021-02-02      False
# 6   7   Oscar   23  Female  72692.50   2021-04-02      False
#
#             Comments
# 4          Dedicated
# 5       Fast Learner
# 6  Needs Improvement

# %%
df.iloc[4:6]
# Out:
#    ID    Name  Age Gender    Salary Joining Date  Is Active      Comments
# 4   5     Eve   34   Male  35428.35   2018-05-19       True     Dedicated
# 5   6  Hannah   23  Other  33952.28   2021-02-02      False  Fast Learner

# %%
df.iloc[4:6, 3:5]
# Out:
#   Gender    Salary
# 4   Male  35428.35
# 5  Other  33952.28

# %%
df.loc[4:6, ['Salary']]
# Out:
#      Salary
# 4  35428.35
# 5  33952.28
# 6  72692.50

# %%
df['resvised_Salary'] = df['Salary']
df.head()
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 0   1    Paul   25  Female  90041.86   2017-01-31      False
# 1   2    Paul   31    Male  90285.02   2019-05-29      False
# 2   3  Rachel   30    Male  84321.65   2022-12-14      False
# 3   4     Bob   45    Male  68189.99   2023-09-05       True
# 4   5     Eve   34    Male  35428.35   2018-05-19       True
#
#             Comments  resvised_Salary
# 0           Creative         90041.86
# 1  Needs Improvement         90285.02
# 2        Hardworking         84321.65
# 3       Fast Learner         68189.99
# 4          Dedicated         35428.35

# %%
df.drop(['resvised_Salary'], axis=1)
# Out:
#        ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 0       1    Paul   25  Female  90041.86   2017-01-31      False
# 1       2    Paul   31    Male  90285.02   2019-05-29      False
# 2       3  Rachel   30    Male  84321.65   2022-12-14      False
# 3       4     Bob   45    Male  68189.99   2023-09-05       True
# 4       5     Eve   34    Male  35428.35   2018-05-19       True
# ..    ...     ...  ...     ...       ...          ...        ...
# 995   996    Jack   58    Male  34288.04   2020-01-18       True
# 996   997    Jack   46   Other  97404.78   2023-11-22       True
# 997   998   Kathy   53    Male  51242.03   2023-05-30       True
# 998   999    Mona   48   Other  34117.08   2017-08-15       True
# 999  1000  Rachel   45  Female  43198.50   2015-12-02       True
#
#               Comments
# 0             Creative
# 1    Needs Improvement
# 2          Hardworking
# 3         Fast Learner
# 4            Dedicated
# ..                 ...
# ...

# %%
df.describe()
# Out:
#                 ID          Age         Salary  resvised_Salary
# count  1000.000000  1000.000000    1000.000000      1000.000000
# mean    500.500000    40.923000   75042.559440     75042.559440
# std     288.819436    11.771476   25839.572122     25839.572122
# min       1.000000    20.000000   30023.460000     30023.460000
# 25%     250.750000    31.000000   52202.320000     52202.320000
# 50%     500.500000    42.000000   75955.130000     75955.130000
# 75%     750.250000    51.000000   96660.315000     96660.315000
# max    1000.000000    60.000000  119880.780000    119880.780000
