# %% [markdown]
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd

# %%
# Load the provided dataset
df = pd.read_csv('/content/drive/MyDrive/xevensol/mlcode/sample_dataset_1000.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load the provided dataset
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/xevensol/mlcode/sample_dataset_1000.csv')
#
# ...

# %%
df.head()
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 0   1    Paul   25  Female  90041.86   2017-01-31      False
# 1   2    Paul   31    Male  90285.02   2019-05-29      False
# 2   3  Rachel   30    Male  84321.65   2022-12-14      False
# 3   4     Bob   45    Male  68189.99   2023-09-05       True
# 4   5     Eve   34    Male  35428.35   2018-05-19       True
#
#             Comments
# 0           Creative
# 1  Needs Improvement
# 2        Hardworking
# 3       Fast Learner
# 4          Dedicated

# %%
# Display basic information
print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# ID                int64
# Name             object
# Age               int64
# Gender           object
# Salary          float64
# Joining Date     object
# Is Active          bool
# Comments         object
# dtype: object

# %% [markdown]
# Columns:
# ID (Integer)
# Name (Text)
# Age (Numerical)
# Gender (Categorical)
# Salary (Float)
# Joining Date (Datetime)
# Is Active (Boolean)
# Comments (Text)

# %%
df.shape
# Out:
# (1000, 8)

# %%
x=df[['Salary']] #Here [[ ]] means we are returning datafram
x.shape
# Out:
# (1000, 1)

# %%
x=df['Salary'] #single bracket means we arer returning series
type(x)
# Out:
# pandas.core.series.Series

# %%
#You can also assign different columns
newvar=df[['Joining Date']]
newvar

# %%
y=df[['Joining Date','Salary']]
y

# %%
q=df[['Joining Date','Salary']]
q

# %%
#df.iloc[:]
#df.iloc[:2]
#df.iloc[0,0:2]
#indexing is like this [start:end:step]
df.iloc[:5,:5] # here [row indexing,column indexing] comma seperates row and columns

# %%
df.iloc[0:2,0:6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.iloc[0:2,0:6]
#
# NameError: name 'df' is not defined

# %%
df.loc[0:2,['Joining Date','Salary']]

# %%
df.loc[4:6]

# %%
df.iloc[3:7]

# %%
df.iloc[5:,:4]

# %%
df['resvised_Salary'] = df['Salary'] #this makes new column "resvised_Salary" and assigns it values of column artist

# %%
df.drop(['resvised_Salary'], axis=1)

# %%
df.drop(['resvised_Salary'], axis=1, inplace=True) #inplace is used to reassign it to the df.
#inplace assigns permanent change
#df=df.drop(['New Artist'], axis=1) this is also possible but not memory effiecient. Inplace is memory efficient
#axis is 0 for row
#axis is 1 for columns

# %%
df.dtypes

# %%
df.describe()
