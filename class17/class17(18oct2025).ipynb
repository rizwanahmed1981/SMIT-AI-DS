# %% [markdown]
# # Positional Argument

# %%
def add(num1, num2, num3):
    print(f'num1: {num1}, num2: {num2}, num3: {num3}')
    return num1 + num2 + num3

# %%
add(4, 5, 6)
# Out:
# num1: 4, num2: 5, num3: 6
# 15

# %% [markdown]
# # Keyword Argument

# %%
# def add(num1, num2, num3):

add(num3=3,num1=4,num2=5)
# Out:
# num1: 4, num2: 5, num3: 3
# 12

# %%
add(4,num3=3,num1=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1968\3477551992.py in <module>
# ----> 1 add(4,num3=3,num1=2)
#
# TypeError: add() got multiple values for argument 'num1'

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1968\3064714114.py in <module>
# ----> 1 add()
#
# TypeError: add() missing 3 required positional arguments: 'num1', 'num2', and 'num3'

# %% [markdown]
# # Default Paramter Values

# %%
def add(num1=1, num2=2, num3=3):
    print(f'num1: {num1}, num2: {num2}, num3: {num3}')
    return num1 + num2 + num3

# %%
add(,,5)
# Out:
#   Cell In[2], line 1
#     add(,,5)
#         ^
# SyntaxError: invalid syntax

# %%
add(num3=3,num1=2)
# Out:
# num1: 2, num2: 2, num3: 3
# 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def display_message():
    print("Today we learned about keyword arguments in python")

display_message()

def fav_book(book):
    print(f"My favorite book is {book.title()}")

fav_book("Applied Mathamatics")
# Out:
# Today we learned about keyword arguments in python
# My favorite book is Applied Mathamatics

# %%
def display_message():
    print('Today we are learning functions')

# %%
display_message()
# Out:
# Today we are learning functions

# %%
def favorite_book(title):
    print(f'One of my favorite books is {title.title()}')

# %%
favorite_book('Pak cricket ki azmaten')
# Out:
# One of my favorite books is Pak Cricket Ki Azmaten

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def make_shirt(size, message):
    print(f"Size: {size.title()} says {message.title()}")

make_shirt("large", "Rizwan is breliant")
# Out:
# Size: Large says Rizwan Is Breliant

# %%
def make_shirt(size="Large", message="I love Python"):
    print(f"Size: {size.title()} says {message.title()}")

make_shirt()
make_shirt("medium")
make_shirt("small", "Pakistan is great")
# Out:
# Size: Large says I Love Python
# Size: Medium says I Love Python
# Size: Small says Pakistan Is Great

# %%
def describe_city(city, country="Pakistan"):
    print(f"city {city.title()} is in {country.title()}")

describe_city("karachi")
describe_city("lahore")
describe_city("dehli", "india")
# Out:
# city Karachi is in Pakistan
# city Lahore is in Pakistan
# city Dehli is in India

# %% [markdown]
# size: 'medium' text:'this is a text'

# %%
def make_shirt(size, text):
    print(f'size: {size}  text: {text}')

# %%
make_shirt('medium', 'There is no text')
# Out:
# size: medium  text: There is no text

# %%
def make_shirt(size='Large', text='I love python'):
    print(f'size: {size}  text: {text}')

# %%
make_shirt()
# Out:
# size: Large  text: I love python

# %%
make_shirt(size='Medium')
# Out:
# size: Medium  text: I love python

# %%
make_shirt(text='I love pakistan')
# Out:
# size: Large  text: I love pakistan

# %%
def describe_city(city, country='Pakistan'):
    print(f'{city} is in {country}')

# %%
describe_city('Lahore')
# Out:
# Lahore is in Pakistan

# %%
def make_album(artist, album):
    result = {artist: album}
    return result

# %%
make_album('atif aslam', 'anyalbum')
# Out:
# {'atif aslam': 'anyalbum'}

# %%
{'imran khan': 'unforgettable'}

# %%
def make_album(artist, album, song=None):
    if song:
        result = {artist: album, 'song':song}
    else:
        result = {artist: album}
    return result

# %%
make_album('imran khan', 'unforgettable')
# Out:
# {'imran khan': 'unforgettable'}

# %%
make_album('atif aslam','kuch bi', 4)
# Out:
# {'atif aslam': 'kuch bi', 'song': 4}

# %%
songs = None

# %%
bool(songs)
# Out:
# False

# %%
songs = 3

# %%
bool(songs)
# Out:
# True

# %%
def make_album():
    flag = True
    result = {}
    while flag:
        artist = input('Enter artist name: ')
        album = input('Enter album name: ')
        result.update({artist: album})
        if artist.lower: #we have error here this should be like """if artist.lower() == "quit": break"""
            # but we dont need this code i think this should be like this "" if artist == "": break""" or flag = False
            break
      
        return result

# %%
make_album()
# Out:
# {'atif aslam': 'kuch bhi'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def make_album(artist, title):
        album = {}
        album["Artist"] = artist
        album["Album"] = title

        print(album)


flag = True

while flag:
    artist = input("Enter artist name : ").title()
    if artist != "":
        title = input("Enter album's title : ").title()
    
        make_album(artist,title)

    else:
         flag = False
# Out:
# {'Artist': 'ali azmat', 'Album': 'na re na'}
# {'Artist': 'abdul basit', 'Album': 'baldia blocks'}
# {'Artist': 'atif aslam', 'Album': 'hawain'}

# %%
def make_album(name, album):
    return {"Artist Name": name.title(), "Album Name": album.title()}
# "Artist Name": {name.title()}, "Album Name": {album.title()}
make_album("Abdull Basit", "From Baldia blocks")
# Out:
# {'Artist Name': 'Abdull Basit', 'Album Name': 'From Baldia Blocks'}

# %%
def make_album(name, album):
    return {"Artist Name": {name.title()}, "Album Name": {album.title()}}
# "Artist Name": {name.title()}, "Album Name": {album.title()}

result = make_album("Abdull Basit", "From Baldia blocks")

print(type(result))
# Out:
# <class 'dict'>

# %%
def make_album(name, album, songs=None):
    if songs:
        return {"Artist Name": name.title(), "Album Name": album.title(), "Songs": songs.title()}
    else:
        return {"Artist Name": name.title(), "Album Name": album.title()}
# "Artist Name": {name.title()}, "Album Name": {album.title()}

make_album("Abdull Basit", "From Baldia blocks", songs="From Baldia blocks To a freelancer")
# Out:
# {'Artist Name': 'Abdull Basit',
#  'Album Name': 'From Baldia Blocks',
#  'Songs': 'From Baldia Blocks To A Freelancer'}

# %%
artist = input("Artist name: ").title()
title = input("Album name: ").title()
album = {}


while artist != "":
    album[artist] = title
    artist = input("Artist name: ").title()
    title = input("Album name: ").title()

print(album)
# Out:
# {'Ahmed': 'Jania', 'Rizwan': 'Sajna Kahan Hoon Tum', 'Sajid': 'Koi Naheen Hay'}

# %%
def make_album():
    album = {}
    flag = True
    while flag:
        artist = input("Artist name: ").title()
        album_title = input("Album name: ").title()
        if artist != "":
            album["Artist"] = artist
            album["Album"] = album_title
        else:
            flag = False
           
    return album

make_album()
# Out:
# {'Artist': 'Ali Azmat', 'Album': 'Na Re Na'}
