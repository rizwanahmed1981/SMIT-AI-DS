# %% [markdown]
# <a href="https://colab.research.google.com/github/rizwanahmed1981/SMIT-AI-DS/blob/main/machine_learning_lacture3_with_%20Dr._Shazia_Saqib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_dataset_1000.csv")

# %%
df.head()
# Out:
#    ID    Name  Age  Gender    Salary Joining Date  Is Active  \
# 0   1    Paul   25  Female  90041.86   2017-01-31      False
# 1   2    Paul   31    Male  90285.02   2019-05-29      False
# 2   3  Rachel   30    Male  84321.65   2022-12-14      False
# 3   4     Bob   45    Male  68189.99   2023-09-05       True
# 4   5     Eve   34    Male  35428.35   2018-05-19       True
#
#             Comments
# 0           Creative
# 1  Needs Improvement
# 2        Hardworking
# 3       Fast Learner
# 4          Dedicated

# %%
df.shape
# Out:
# (1000, 8)
